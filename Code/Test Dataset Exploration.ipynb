# %%
import pandas as pd

# %%
pred_df = pd.read_csv("../Data/Assignment3-UnknownData.csv")

# %%
pred_df.describe()
# Out:
#              BATHRM     HF_BATHRM          HEAT     NUM_UNITS         ROOMS  \
# count  32140.000000  32140.000000  32140.000000  32140.000000  32135.000000
# mean       2.027442      0.603983      7.652582      1.203267      7.366423
# std        1.057538      0.614689      5.042002      0.604984      2.327141
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      1.000000      1.000000      6.000000
# 50%        2.000000      1.000000      7.000000      1.000000      7.000000
# 75%        3.000000      1.000000     13.000000      1.000000      8.000000
# max       13.000000      6.000000     13.000000      5.000000     41.000000
#
#               BEDRM           AYB       YR_RMDL           EYB       STORIES  \
# count  32140.000000  32144.000000  14912.000000  32147.000000  32125.000000
# mean       3.373024   1928.372138   2000.762607   1965.562168      2.082627
# ...

# %%
pred_df[pred_df['AYB'] <= 1500]
# Out:
#          row ID  BATHRM  HF_BATHRM  HEAT         HEAT_D AC  NUM_UNITS  ROOMS  \
# 1027    Row1027     2.0        1.0   1.0     Forced Air  Y        2.0    7.0
# 1267    Row1267     3.0        0.0  13.0  Hot Water Rad  N        2.0   16.0
# 1355    Row1355     2.0        0.0   1.0     Forced Air  Y        1.0    7.0
# 1542    Row1542     2.0        2.0   1.0     Forced Air  Y        2.0   10.0
# 1605    Row1605     4.0        0.0   1.0     Forced Air  Y        4.0    8.0
# ...         ...     ...        ...   ...            ... ..        ...    ...
# 26787  Row26787     1.0        0.0   1.0     Forced Air  Y        1.0    6.0
# 27099  Row27099     1.0        0.0   1.0     Forced Air  Y        1.0    6.0
# 27631  Row27631     4.0        0.0  13.0  Hot Water Rad  N        4.0   12.0
# 30156  Row30156     4.0        0.0  13.0  Hot Water Rad  N        4.0   16.0
# 31253  Row31253     4.0        0.0  13.0  Hot Water Rad  N        2.0   10.0
#
# ...

# %%
pred_df.loc[pred_df.isnull().mean(axis=1) >= 0.1]
# Out:
#          row ID  BATHRM  HF_BATHRM  HEAT HEAT_D   AC  NUM_UNITS  ROOMS  BEDRM  \
# 12535  Row12535     NaN        NaN   NaN    NaN  NaN        NaN    NaN    NaN
# 17963  Row17963     NaN        NaN   NaN    NaN  NaN        NaN    NaN    NaN
# 20383  Row20383     NaN        NaN   NaN    NaN  NaN        NaN    NaN    NaN
# 20384  Row20384     NaN        NaN   NaN    NaN  NaN        NaN    NaN    NaN
# 20385  Row20385     NaN        NaN   NaN    NaN  NaN        NaN    NaN    NaN
# 20386  Row20386     NaN        NaN   NaN    NaN  NaN        NaN    NaN    NaN
# 20387  Row20387     NaN        NaN   NaN    NaN  NaN        NaN    NaN    NaN
#
#           AYB  ...  EXTWALL_D  ROOF  ROOF_D INTWALL  INTWALL_D  KITCHENS  \
# 12535  2019.0  ...        NaN   NaN     NaN     NaN        NaN       NaN
# 17963  1895.0  ...        NaN   NaN     NaN     NaN        NaN       NaN
# 20383  2019.0  ...        NaN   NaN     NaN     NaN        NaN       NaN
# ...
